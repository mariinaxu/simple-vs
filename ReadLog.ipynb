# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = "/home/k1n4s3/LABSERVER6/Personal/Federico/GitRepos/simple-vs/data-1-1005.npy"

# %%
log = np.load(file)

# %%
log.shape
# Out:
# (17, 8, 1000)

# %%
plt.figure()
plt.imshow(log[0, :, :], aspect='auto')

# %%
plt.figure()
plt.plot(log[10, 1, :])
